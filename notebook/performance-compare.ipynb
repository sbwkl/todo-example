# %%
import pandas as pd
import datetime

# %%
day = datetime.datetime.now().strftime('%Y-%m-%d')

# %%
p1 = pd.read_csv('C:/Users/wayne.wang/Downloads/warehouse-sum-v1 {}.csv'.format(day))
p2 = pd.read_csv('C:/Users/wayne.wang/Downloads/warehouse-sum-v2 {}.csv'.format(day))

pc = p1[['cost_date', 'warehouse', 'order_num']]
# pc['match'] = p1['warehouse'] == p2['warehouse']
pc['order_num_v2'] = p2['order_num']
pc['order_num_diff'] = p1['order_num'] - p2['order_num']

costs = ['total_cost', 'person_cost_actual', 'daily_cost_actual', 'consume_cost_actual', 'express_cost_actual', 'custom_cost_actual', 'platform_cost_actual', 'undertake_cost_actual', 'house_cost_actual', 'fixed_cost_actual']

select_columns_base = ['total', 'express']
for text in costs:
    c = text.split('_')[0]
    pc[c] = p1[text]
    pc[c + '_v2'] = p2[text]
    pc[c + '_diff'] = p1[text] - p2[text]
    pc[c + '_diff/order'] = pc[c + '_diff'] / pc['order_num']
# pc['cost_date'] = pc['cost_date'].apply(lambda x: x[:10])
pc['cost_date'] = '5.1-5.16'
select_columns_actual = ['cost_date', 'warehouse', 'order_num', 'order_num_v2', 'order_num_diff']
for s in select_columns_base:
    select_columns_actual.append(s)
    select_columns_actual.append(s + '_v2')
    select_columns_actual.append(s + '_diff')
    select_columns_actual.append(s + '_diff/order')
    
pc[select_columns_actual]

# pc.loc[pc['total_diff/order'].abs() >= 0.1]

# %%
p1 = pd.read_csv('C:/Users/wayne.wang/Downloads/warehouse-daily-v1 {}.csv'.format(day, day))
p2 = pd.read_csv('C:/Users/wayne.wang/Downloads/warehouse-daily-v2 {}.csv'.format(day, day))

pc = p1[['cost_date', 'warehouse', 'order_num', 'good_num']]
# pc['match'] = p1['warehouse'] == p2['warehouse']
pc['order_num_v2'] = p2['order_num']
pc['order_num_diff'] = p1['order_num'] - p2['order_num']

pc['good_num_v2'] = p2['good_num']
pc['good_num_diff'] = p1['good_num'] - p2['good_num']

costs = ['total_cost', 'person_cost_actual', 'daily_cost_actual', 'consume_cost_actual', 'express_cost_actual', 'custom_cost_actual', 'platform_cost_actual', 'undertake_cost_actual', 'house_cost_actual', 'fixed_cost_actual']

select_columns_base = ['daily', 'custom', 'fixed']
diff_columns = []
for text in costs:
    c = text.split('_')[0]
    pc[c] = p1[text]
    pc[c + '_v2'] = p2[text]
    pc[c + '_diff'] = p1[text] - p2[text]
    pc[c + '_diff/order'] = pc[c + '_diff'] / pc['order_num']
    diff_columns.append(c + '_diff')
pc['cost_date'] = pc['cost_date'].apply(lambda x: x[:10])

select_columns_actual = ['cost_date', 'warehouse', 'order_num', 'order_num_v2', 'order_num_diff', 'good_num', 'good_num_v2', 'good_num_diff']

for s in select_columns_base:
    select_columns_actual.append(s)
    select_columns_actual.append(s + '_v2')
    select_columns_actual.append(s + '_diff')
    select_columns_actual.append(s + '_diff/order')
    
# pc[select_columns_actual].to_csv('2019-05-16/warehouse-daily-diff.csv')
pc[select_columns_actual]
pc['差异较大'] = pc['total_diff/order'].abs() > 0.2
pc.loc[(pc['total_diff/order'].abs() >= 0.2) & (pc['warehouse'] != '1HD8')][['cost_date', 'warehouse', 'order_num', 'order_num_v2', 'order_num_diff', 'good_num_diff'] + diff_columns]
pc.loc[(pc['cost_date'] >= '2019-05-17') & pc['total_diff'] != 0][['cost_date', 'warehouse', 'order_num', 'order_num_v2', 'order_num_diff', 'good_num_diff'] + diff_columns]
pc.loc[(pc['cost_date'] >= '2019-05-17') & pc['total_diff'] != 0][select_columns_actual]
# Out:
# C:\Users\wayne.wang\py36\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\wayne.wang\py36\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# C:\Users\wayne.wang\py36\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# C:\Users\wayne.wang\py36\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.
# C:\Users\wayne.wang\py36\lib\site-packages\ipykernel_launcher.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\wayne.wang\py36\lib\site-packages\ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\wayne.wang\py36\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\wayne.wang\py36\lib\site-packages\ipykernel_launcher.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#       cost_date warehouse  order_num  order_num_v2  order_num_diff  good_num  \
# 157  2019-05-17       HD7       6514          6514               0      9162
# 160  2019-05-17      HGH1       7332          7356             -24     11263
# 163  2019-05-17      NGB2        868           868               0      1697
# 167  2019-05-18       HD7       5514          5514               0      8346
# 170  2019-05-18      HGH1       7721          7735             -14     12383
# 173  2019-05-18      NGB2        779           779               0      1516
# 177  2019-05-19       HD7       4380          4380               0      6668
# 180  2019-05-19      HGH1       5634          5654             -20      8887
# 182  2019-05-19      NGB2        578           578               0      1069
#
#      good_num_v2  good_num_diff  daily  daily_v2  daily_diff  \
# 157         9162              0      0    651.40     -651.40
# 160        11344            -81      0    735.60     -735.60
# 163         1697              0      0    130.20     -130.20
# 167         8346              0      0    551.40     -551.40
# 170        12418            -35      0    773.50     -773.50
# 173         1516              0      0    116.85     -116.85
# 177         6668              0      0    438.00     -438.00
# 180         8955            -68      0    565.40     -565.40
# 182         1069              0      0     86.70      -86.70
#
#      daily_diff/order   custom  custom_v2  custom_diff  custom_diff/order  \
# 157         -0.100000     0.00       0.00         0.00           0.000000
# 160         -0.100327  5950.89    5988.47       -37.58          -0.005125
# 163         -0.150000  1531.28    1531.28         0.00           0.000000
# 167         -0.100000     0.00       0.00         0.00           0.000000
# 170         -0.100181  6573.65    6589.83       -16.18          -0.002096
# 173         -0.150000  1531.06    1531.06         0.00           0.000000
# 177         -0.100000     0.00       0.00         0.00           0.000000
# 180         -0.100355  4650.99    4681.79       -30.80          -0.005467
# 182         -0.150000  1106.50    1106.50         0.00           0.000000
#
#       fixed  fixed_v2  fixed_diff  fixed_diff/order
# 157    0.00      0.00        0.00          0.000000
# 160  509.57   1027.63     -518.06         -0.070657
# 163    0.00      0.00        0.00          0.000000
# 167    0.00      0.00        0.00          0.000000
# 170  509.59   1027.98     -518.39         -0.067140
# 173    0.00      0.00        0.00          0.000000
# 177    0.00      0.00        0.00          0.000000
# 180  509.31   1027.33     -518.02         -0.091945
# 182    0.00      0.00        0.00          0.000000

# %%
p1 = pd.read_csv('C:/Users/wayne.wang/Downloads/SQLPad Query Results 2019-05-17-1.csv'.format(day, day))
p2 = pd.read_csv('C:/Users/wayne.wang/Downloads/SQLPad Query Results 2019-05-17.csv'.format(day, day))

s1 = set(p1['shipping_no'].tolist())
s2 = set(p2['shipping_no'].tolist())
s1 - s2
